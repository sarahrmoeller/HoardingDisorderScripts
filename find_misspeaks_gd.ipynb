# %%
import utils.data.datasaur as datasaur

misspeak_gd_docs = [doc for doc in datasaur.docs 
                 if doc.label_counts["Misspeak–Participant"] > 0 or
                    doc.label_counts["Generic Disfluency–Participant"] > 0]
len(misspeak_gd_docs)
# Out:
# c:\Users\Daniel\Dev\HoardingDisorderScripts\utils\document.py:217: UserWarning: First 2 rows (out of 15) empty in DatasaurDocument(2008_118.txt, s1036-42_s2008-9_s3000-15-NTliMzIxODk), but there are too many speakers! I don't know how to fill them.
#   warnings.warn(f'First {i+1} rows (out of '
# c:\Users\Daniel\Dev\HoardingDisorderScripts\utils\document.py:217: UserWarning: First 3 rows (out of 15) empty in DatasaurDocument(2008_118.txt, s1036-42_s2008-9_s3000-15-NTliMzIxODk), but there are too many speakers! I don't know how to fill them.
#   warnings.warn(f'First {i+1} rows (out of '
# c:\Users\Daniel\Dev\HoardingDisorderScripts\utils\document.py:217: UserWarning: First 4 rows (out of 15) empty in DatasaurDocument(2008_118.txt, s1036-42_s2008-9_s3000-15-NTliMzIxODk), but there are too many speakers! I don't know how to fill them.
#   warnings.warn(f'First {i+1} rows (out of '
# ...

# %%
import random

random.seed(123)
samp = random.sample(misspeak_gd_docs, 100)

# %%
from pprint import pprint

ind = 0
pprint(samp[0].label_text())
print(samp[0].full_text)
# Out:
# defaultdict(<class 'list'>,
#             {'Generic Disfluency': ['I actually have...'],
#              'Incomplete Thought': ['so.']})
# Interviewer:
# Okay. So, what are you collections that make of most of the stuff that you have in storage?
# What is it?
# Is it a lot of photos, a lot of books, or...
# Participant 009:
# In storage or collections, because I actually have... I collect things that I display.
# [crosstalk 00:23:19].
# Interviewer:
# Well, yeah, let's hear about both.
# Participant 009:
# Such as I have a collection of egg cups and I've limited myself by the display space I have in the kitchen.
# So, I have egg cups, I have elephants that I've collected over the years, all these figurines of elephants that are on display.
# I have art and things like that that's displayed around the house in different places, so that's what I consider a collection.
# Did that answer your question?
# Interviewer:
# So, then what is in all the boxes that you have in your garage?
# ...
