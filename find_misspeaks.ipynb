# %%
import utils.data.datasaur as datasaur

misspeak_docs = [doc for doc in datasaur.docs 
                 if doc.label_counts["Misspeak–Participant"] > 0]
len(misspeak_docs)
# Out:
# c:\Users\Daniel\Dev\HoardingDisorderScripts\utils\document.py:217: UserWarning: First 2 rows (out of 15) empty in DatasaurDocument(2008_118.txt, s1036-42_s2008-9_s3000-15-NTliMzIxODk), but there are too many speakers! I don't know how to fill them.
#   warnings.warn(f'First {i+1} rows (out of '
# c:\Users\Daniel\Dev\HoardingDisorderScripts\utils\document.py:217: UserWarning: First 3 rows (out of 15) empty in DatasaurDocument(2008_118.txt, s1036-42_s2008-9_s3000-15-NTliMzIxODk), but there are too many speakers! I don't know how to fill them.
#   warnings.warn(f'First {i+1} rows (out of '
# c:\Users\Daniel\Dev\HoardingDisorderScripts\utils\document.py:217: UserWarning: First 4 rows (out of 15) empty in DatasaurDocument(2008_118.txt, s1036-42_s2008-9_s3000-15-NTliMzIxODk), but there are too many speakers! I don't know how to fill them.
#   warnings.warn(f'First {i+1} rows (out of '
# ...

# %%
from pprint import pprint

ind = 9
print(misspeak_docs[ind].label_text())
pprint(misspeak_docs[ind].full_text)
# Out:
# defaultdict(<class 'list'>, {'Misspeak': ['So stuff like that just needs a better away space,']})
# ('Interviewer:\n'
#  "Okay. So the next thing you briefly covered it, but we're going to talk "
#  'about space and living area.\n'
#  'So can you please describe like where you live now and what the space looks '
#  'like?\n'
#  'Participant 015:\n'
#  "It's just my husband and myself.\n"
#  "But when we moved in here there was the five kids with us, and they've all "
#  'gone on their own.\n'
#  "So we have a five bedroom house that's 2,600 square feet and pretty good "
#  'sized property too.\n'
#  "About a third of an acre in the suburbs and it's a colonial, so all the five "
#  "bedrooms are upstairs and then it's got a basement as well, two car attached "
#  'garage.\n'
#  "So it's nice, but it's not super duper grand.\n"
#  'Interviewer:\n'
#  'All right.\n'
#  'And so you mentioned before that none of the doorways or anything are '
# ...
